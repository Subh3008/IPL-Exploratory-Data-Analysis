# %%
#importing all the necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # loading the data

# %% [markdown]
# extracting all the necessary information from the data

# %%
#extracting the data from the csv file using pandas

df=pd.read_csv('IPLData.csv')
df
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 0     Shikhar Dhawan     Punjab      Indian      Batter       1
# 1      Shreyas Iyer     Kolkata      Indian      Batter       1
# 2     Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3     Manish Pandey     Lucknow      Indian      Batter       1
# 4    Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# ..               ...        ...         ...         ...     ...
# 230     Ravi Bishnoi    Lucknow      Indian     Bowler        1
# 231  Ruturaj Gaikwad    Chennai      Indian      Batter       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 234    Anrich Nortje      Delhi    Overseas     Bowler        1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 0             192.0  5783.0    34.63       126.60      4.0            16.50
# ...

# %%
#shape of the data
df.shape
# Out:
# (235, 16)

# %% [markdown]
# HENCE NUMBER OF ROWS=235 WHICH REPRESENTS THE NUMBER OF PLAYERS PARTICIPATING IN THE IPL

# %%
#DISPLAYING THE COLUMNS OF THE DATA
df.columns
# Out:
# Index(['Player Name', 'Team', 'Nationality', 'Player_Type', 'Capped',
#        'Matches_Played', 'Runs', 'Average', 'Strike_Rate', 'Wickets',
#        'Bowling_average', 'Economy', 'Bowling_Strike_Rate', 'Catches',
#        'Run_outs', 'Stumps'],
#       dtype='object')

# %%
#first look of the data using head function
df.head()
# Out:
#        Player Name       Team Nationality Player_Type  Capped  Matches_Played  \
# 0   Shikhar Dhawan     Punjab      Indian      Batter       1           192.0
# 1    Shreyas Iyer     Kolkata      Indian      Batter       1            87.0
# 2   Faf Du Plessis  Bangalore    Overseas      Batter       1           100.0
# 3   Manish Pandey     Lucknow      Indian      Batter       1           154.0
# 4  Shimron Hetmyer  Rajasthan    Overseas      Batter       1            31.0
#
#      Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 0  5783.0    34.63       126.60      4.0             16.5     8.25
# 1  2375.0    31.67       123.96      NaN              NaN      NaN
# 2  2935.0    34.94       131.09      NaN              NaN      NaN
# 3  3560.0    30.69       121.83      NaN              NaN      NaN
# 4   517.0    25.85       151.17      NaN              NaN      NaN
#
#    Bowling_Strike_Rate  Catches  Run_outs  Stumps
# ...

# %%
#describe functionwill return the necessary information from the dataset like count, mean, standard deviation etc
df.describe()
# Out:
#            Capped  Matches_Played         Runs     Average  Strike_Rate  \
# count  235.000000      215.000000   165.000000  161.000000   163.000000
# mean     0.838298       43.897674   840.575758   21.792391   121.009939
# std      0.561802       48.695302  1270.341831   11.664156    30.739189
# min      0.000000        1.000000     0.000000    0.000000     0.000000
# 25%      0.500000       11.500000    67.000000   13.800000   112.635000
# 50%      1.000000       25.000000   289.000000   22.410000   128.630000
# 75%      1.000000       56.000000   954.000000   29.300000   137.550000
# max      2.000000      220.000000  6283.000000   58.500000   190.240000
#
#           Wickets  Bowling_average     Economy  Bowling_Strike_Rate  \
# count  140.000000       135.000000  143.000000           119.000000
# mean    31.485714        32.907185    8.223182            24.686134
# std     36.872420        18.191441    1.223541            12.982049
# ...

# %%
#we use isnull().sums() method to check the number of null values
df.isnull().sum()
# Out:
# Player Name              0
# Team                     0
# Nationality              0
# Player_Type              0
# Capped                   0
# Matches_Played          20
# Runs                    70
# Average                 74
# Strike_Rate             72
# Wickets                 95
# Bowling_average        100
# Economy                 92
# Bowling_Strike_Rate    116
# Catches                208
# Run_outs               208
# Stumps                 208
# dtype: int64

# %%
#we use info method to get the information about the dataset like non null objects and the data type of each elements in the given data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          235 non-null    object
#  1   Team                 235 non-null    object
#  2   Nationality          235 non-null    object
#  3   Player_Type          235 non-null    object
#  4   Capped               235 non-null    int64
#  5   Matches_Played       215 non-null    float64
#  6   Runs                 165 non-null    float64
#  7   Average              161 non-null    float64
#  8   Strike_Rate          163 non-null    float64
#  9   Wickets              140 non-null    float64
#  10  Bowling_average      135 non-null    float64
#  11  Economy              143 non-null    float64
#  12  Bowling_Strike_Rate  119 non-null    float64
#  13  Catches              27 non-null     float64
#  14  Run_outs             27 non-null     float64
# ...

# %% [markdown]
# # cleaning the data

# %% [markdown]
# in the above data the players are segregated based on the following parameters
#
#  1.CAPPED-BATTERS,BOWLERS,ALLROUNDERS,WICKET-KEEPPER
#  2.UNCAPPED-BATTERS,BOWLERS,ALLROUNDERS,WICKET-KEEPPER
#
# THE UNCAPPED PLAYERS ARE PLAYING FOR THE FIRST TIME SO THERE IS NO RELEVANT DATA AVAILABLE ABOUT THEIR T20 PERFORMANCES

# %%
#SEGREGATING DATA = CAPPED BATTERS
batters=df.loc[(df['Player_Type']=='Batter')]
batters_new=batters.loc[(batters['Capped']==1)]
capped_batters=batters_new[['Player Name','Team','Nationality','Matches_Played','Runs','Average','Strike_Rate']]
capped_batters.head()
# Out:
#        Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0   Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1    Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2   Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 3   Manish Pandey     Lucknow      Indian           154.0  3560.0    30.69
# 4  Shimron Hetmyer  Rajasthan    Overseas            31.0   517.0    25.85
#
#    Strike_Rate
# 0       126.60
# 1       123.96
# 2       131.09
# 3       121.83
# 4       151.17

# %%
#cleaning the capped_batters data by making the null or NAN vcalues 0 using fillna()
#later checking if there is any null value present or not using isnull.sum()
capped_batters=capped_batters.fillna(0)
capped_batters.isnull().sum()
# Out:
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# dtype: int64

# %%
#SEGRAGATING DATA=CAPPED ALLROUNDERS

allrounders=df.loc[(df['Player_Type'] =='Allrounder')]
allrounders_new=allrounders.loc[(allrounders['Capped']==1)]
capped_allrounders=allrounders_new[['Player Name','Matches_Played','Team','Nationality','Runs','Average','Strike_Rate','Wickets','Bowling_average','Economy','Bowling_Strike_Rate']]
capped_allrounders.head()
# Out:
#               Player Name  Matches_Played       Team Nationality    Runs  \
# 127  Ravichandran Ashwin            167.0  Rajasthan      Indian   456.0
# 128          Pat Cummins             37.0    Kolkata    Overseas   316.0
# 129         Dwayne Bravo            151.0    Chennai    Overseas  1537.0
# 130          Nitish Rana             77.0    Kolkata      Indian  1820.0
# 131          Jason Holder            26.0    Lucknow    Overseas   189.0
#
#      Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 127    11.12       109.88    145.0            27.80     6.91
# 128    19.75       140.44     38.0            30.13     8.24
# 129    22.94       130.25    167.0            24.32     8.36
# 130    28.00       132.46      7.0            22.00     8.03
# 131    14.54       121.15     35.0            22.46     8.20
#
#      Bowling_Strike_Rate
# 127                24.12
# 128                21.95
# 129                17.44
# 130                16.43
# 131                16.43

# %%
#cleaning the capped_allrounderrs data by making the null or NAN vcalues 0 using fillna()
#later checking if there is any null value present or not using isnull.sum()

capped_allrounders=capped_allrounders.fillna(0)
capped_allrounders.isnull().sum()
# Out:
# Player Name            0
# Matches_Played         0
# Team                   0
# Nationality            0
# Runs                   0
# Average                0
# Strike_Rate            0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64

# %%
#SEGRAGATING DATA=CAPPED WICKET KEEPERS

WKs=df.loc[(df['Player_Type'] =='Keeper')]
WKs_new=WKs.loc[(WKs['Capped']==1)]
capped_WKs=WKs_new[['Player Name','Matches_Played','Team','Nationality','Runs','Average','Strike_Rate','Catches','Stumps','Run_outs']]
capped_WKs.head()
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 105  Quinton De Kock            77.0    Lucknow    Overseas  2256.0     31.3
# 106    Ambati Rayudu           175.0    Chennai      Indian  3916.0     29.4
# 107     Ishan Kishan            61.0     Mumbai      Indian  1452.0     28.5
# 108   Jonny Bairstow            28.0     Punjab    Overseas  1038.0     41.5
# 109   Dinesh Karthik           213.0  Bangalore      Indian  4046.0     25.8
#
#      Strike_Rate  Catches  Stumps  Run_outs
# 105        130.9     53.0    14.0       0.0
# 106        127.5     58.0     2.0      12.0
# 107        136.3     19.0     2.0       1.0
# 108        142.2     18.0     4.0       1.0
# 109        129.7    123.0    32.0      14.0

# %%
# cleaning the capped_wicketkeepers data by making the null or NAN vcalues 0 using fillna()
#later checking if there is any null value present or not using isnull.sum()

capped_WKs=capped_WKs.fillna(0)
capped_WKs.isnull().sum()
# Out:
# Player Name       0
# Matches_Played    0
# Team              0
# Nationality       0
# Runs              0
# Average           0
# Strike_Rate       0
# Catches           0
# Stumps            0
# Run_outs          0
# dtype: int64

# %% [markdown]
# # data analysis

# %% [markdown]
# HERE WE WILL ANALYSE THE DATA OF THE CAPPED BATSMEN,ALLROUNDERS,WICKET-KEEPERS

# %%
#ANALYSIS OF DATA OF BATTERS WITH AVERAGE MORE THAN OR EQUAL TO 32.00
top_batters=capped_batters.loc[(capped_batters['Average']>=32)]
top_batters
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 0         126.60
# 2         131.09
# 19        139.97
# 26        136.51
# 207       131.27
# 208       129.95
# 212       136.38
# 231       132.13

# %%
#sorting the top_batters data in descending order with respect to each parameters
top_batters_avg=top_batters.sort_values('Average',ascending=False)
top_batters_SR=top_batters.sort_values('Strike_Rate',ascending=False)
top_batters_runs=top_batters.sort_values('Runs',ascending=False)
top_batters_matches=top_batters.sort_values('Matches_Played',ascending=False)

# %%
#top 8 batters with most average

top_batters_avg
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
#
#      Strike_Rate
# 212       136.38
# 231       132.13
# 19        139.97
# 207       131.27
# 208       129.95
# 2         131.09
# 0         126.60
# 26        136.51

# %%
#top 8 batters with most strike rate

top_batters_SR
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
#
#      Strike_Rate
# 19        139.97
# 26        136.51
# 212       136.38
# 231       132.13
# 207       131.27
# 2         131.09
# 208       129.95
# 0         126.60

# %%
#top 8 batters with most runs

top_batters_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 212       136.38
# 2         131.09
# 26        136.51
# 207       131.27
# 231       132.13

# %%
#top 8 batters with most matches played
top_batters_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 2         131.09
# 212       136.38
# 26        136.51
# 207       131.27
# 231       132.13

# %% [markdown]
# after analyzing the data we can see that
# 1.Virat Kohli has played most number of matches till now
# 2.Virat Kohli also has the most number of runs till now
# 3.David Werner has the highest strike rate among all the batters present in the list and
# 4.KL Rahul has the highest average among all the batters present in the list

# %%
#analyzing the allrounder data with strike rate more than 139.0
top_allrounders=capped_allrounders.loc[(capped_allrounders['Strike_Rate']>=139.0)]
top_allrounders
# Out:
#            Player Name  Matches_Played       Team Nationality    Runs  \
# 128       Pat Cummins             37.0    Kolkata    Overseas   316.0
# 139   Abhishek Sharma             22.0  Hyderabad      Indian   241.0
# 154         K Gowtham             24.0    Lucknow      Indian   186.0
# 165       Jofra Archer            35.0     Mumbai    Overseas   195.0
# 169  Mithchel Santner              6.0    Chennai    Overseas    32.0
# 195     Mohammad Nabi             17.0    Kolkata    Overseas   180.0
# 202         Aman Khan              5.0    Kolkata      Indian    40.0
# 204      Andre Russell            84.0    Kolkata    Overseas  1700.0
# 211      Hardik Pandya            92.0    Gujarat      Indian  1476.0
# 218       Glen Maxwell            97.0  Bangalore    Overseas  2018.0
# 223          Moeen Ali            34.0    Chennai    Overseas   666.0
# 232      Sunil Narine            134.0    Kolkata    Overseas   954.0
# ...

# %%
#sorting the top_allrounders data in descending order with respect to each parameters
top_allrounder_matches=top_allrounders.sort_values('Matches_Played',ascending=False)
top_allrounder_runs=top_allrounders.sort_values('Runs',ascending=False)
top_allrounder_avg=top_allrounders.sort_values('Average',ascending=False)
top_allrounder_SR=top_allrounders.sort_values('Strike_Rate',ascending=False)
top_allrounder_WK=top_allrounders.sort_values('Wickets',ascending=False)
top_allrounder_Bowling_AVG=top_allrounders.sort_values('Bowling_average',ascending=True)
top_allrounder_eco=top_allrounders.sort_values('Economy',ascending=True)
top_allrounder_Bowling_SR=top_allrounders.sort_values('Bowling_Strike_Rate',ascending=True)

# %%
#top allrounders with most appearances
top_allrounder_matches
# Out:
#            Player Name  Matches_Played       Team Nationality    Runs  \
# 233    Kieron Pollard            178.0     Mumbai    Overseas  3268.0
# 232      Sunil Narine            134.0    Kolkata    Overseas   954.0
# 218       Glen Maxwell            97.0  Bangalore    Overseas  2018.0
# 211      Hardik Pandya            92.0    Gujarat      Indian  1476.0
# 204      Andre Russell            84.0    Kolkata    Overseas  1700.0
# 128       Pat Cummins             37.0    Kolkata    Overseas   316.0
# 165       Jofra Archer            35.0     Mumbai    Overseas   195.0
# 223          Moeen Ali            34.0    Chennai    Overseas   666.0
# 154         K Gowtham             24.0    Lucknow      Indian   186.0
# 139   Abhishek Sharma             22.0  Hyderabad      Indian   241.0
# 195     Mohammad Nabi             17.0    Kolkata    Overseas   180.0
# 169  Mithchel Santner              6.0    Chennai    Overseas    32.0
# ...

# %%
#top allrounders with highest runs
top_allrounder_runs
# Out:
#            Player Name  Matches_Played       Team Nationality    Runs  \
# 233    Kieron Pollard            178.0     Mumbai    Overseas  3268.0
# 218       Glen Maxwell            97.0  Bangalore    Overseas  2018.0
# 204      Andre Russell            84.0    Kolkata    Overseas  1700.0
# 211      Hardik Pandya            92.0    Gujarat      Indian  1476.0
# 232      Sunil Narine            134.0    Kolkata    Overseas   954.0
# 223          Moeen Ali            34.0    Chennai    Overseas   666.0
# 128       Pat Cummins             37.0    Kolkata    Overseas   316.0
# 139   Abhishek Sharma             22.0  Hyderabad      Indian   241.0
# 165       Jofra Archer            35.0     Mumbai    Overseas   195.0
# 154         K Gowtham             24.0    Lucknow      Indian   186.0
# 195     Mohammad Nabi             17.0    Kolkata    Overseas   180.0
# 202         Aman Khan              5.0    Kolkata      Indian    40.0
# ...

# %%
#top allrounders with highest average in batting
top_allrounder_avg
# Out:
#            Player Name  Matches_Played       Team Nationality    Runs  \
# 169  Mithchel Santner              6.0    Chennai    Overseas    32.0
# 233    Kieron Pollard            178.0     Mumbai    Overseas  3268.0
# 204      Andre Russell            84.0    Kolkata    Overseas  1700.0
# 211      Hardik Pandya            92.0    Gujarat      Indian  1476.0
# 218       Glen Maxwell            97.0  Bangalore    Overseas  2018.0
# 223          Moeen Ali            34.0    Chennai    Overseas   666.0
# 128       Pat Cummins             37.0    Kolkata    Overseas   316.0
# 139   Abhishek Sharma             22.0  Hyderabad      Indian   241.0
# 232      Sunil Narine            134.0    Kolkata    Overseas   954.0
# 165       Jofra Archer            35.0     Mumbai    Overseas   195.0
# 195     Mohammad Nabi             17.0    Kolkata    Overseas   180.0
# 154         K Gowtham             24.0    Lucknow      Indian   186.0
# ...

# %%
#top allrounders with highest strike rate
top_allrounder_SR
# Out:
#            Player Name  Matches_Played       Team Nationality    Runs  \
# 204      Andre Russell            84.0    Kolkata    Overseas  1700.0
# 154         K Gowtham             24.0    Lucknow      Indian   186.0
# 232      Sunil Narine            134.0    Kolkata    Overseas   954.0
# 165       Jofra Archer            35.0     Mumbai    Overseas   195.0
# 211      Hardik Pandya            92.0    Gujarat      Indian  1476.0
# 218       Glen Maxwell            97.0  Bangalore    Overseas  2018.0
# 195     Mohammad Nabi             17.0    Kolkata    Overseas   180.0
# 233    Kieron Pollard            178.0     Mumbai    Overseas  3268.0
# 202         Aman Khan              5.0    Kolkata      Indian    40.0
# 223          Moeen Ali            34.0    Chennai    Overseas   666.0
# 128       Pat Cummins             37.0    Kolkata    Overseas   316.0
# 139   Abhishek Sharma             22.0  Hyderabad      Indian   241.0
# ...

# %%
#top allrounders with highest wickets
top_allrounder_WK
# Out:
#            Player Name  Matches_Played       Team Nationality    Runs  \
# 232      Sunil Narine            134.0    Kolkata    Overseas   954.0
# 204      Andre Russell            84.0    Kolkata    Overseas  1700.0
# 233    Kieron Pollard            178.0     Mumbai    Overseas  3268.0
# 165       Jofra Archer            35.0     Mumbai    Overseas   195.0
# 211      Hardik Pandya            92.0    Gujarat      Indian  1476.0
# 128       Pat Cummins             37.0    Kolkata    Overseas   316.0
# 218       Glen Maxwell            97.0  Bangalore    Overseas  2018.0
# 223          Moeen Ali            34.0    Chennai    Overseas   666.0
# 154         K Gowtham             24.0    Lucknow      Indian   186.0
# 195     Mohammad Nabi             17.0    Kolkata    Overseas   180.0
# 139   Abhishek Sharma             22.0  Hyderabad      Indian   241.0
# 169  Mithchel Santner              6.0    Chennai    Overseas    32.0
# ...

# %%
#top allrounder with highest bowling average
top_allrounder_Bowling_AVG
# Out:
#            Player Name  Matches_Played       Team Nationality    Runs  \
# 202         Aman Khan              5.0    Kolkata      Indian    40.0
# 165       Jofra Archer            35.0     Mumbai    Overseas   195.0
# 169  Mithchel Santner              6.0    Chennai    Overseas    32.0
# 232      Sunil Narine            134.0    Kolkata    Overseas   954.0
# 139   Abhishek Sharma             22.0  Hyderabad      Indian   241.0
# 204      Andre Russell            84.0    Kolkata    Overseas  1700.0
# 223          Moeen Ali            34.0    Chennai    Overseas   666.0
# 128       Pat Cummins             37.0    Kolkata    Overseas   316.0
# 211      Hardik Pandya            92.0    Gujarat      Indian  1476.0
# 195     Mohammad Nabi             17.0    Kolkata    Overseas   180.0
# 233    Kieron Pollard            178.0     Mumbai    Overseas  3268.0
# 218       Glen Maxwell            97.0  Bangalore    Overseas  2018.0
# ...

# %%
#top allrounder with highest economy
top_allrounder_eco
# Out:
#            Player Name  Matches_Played       Team Nationality    Runs  \
# 232      Sunil Narine            134.0    Kolkata    Overseas   954.0
# 223          Moeen Ali            34.0    Chennai    Overseas   666.0
# 169  Mithchel Santner              6.0    Chennai    Overseas    32.0
# 202         Aman Khan              5.0    Kolkata      Indian    40.0
# 165       Jofra Archer            35.0     Mumbai    Overseas   195.0
# 195     Mohammad Nabi             17.0    Kolkata    Overseas   180.0
# 139   Abhishek Sharma             22.0  Hyderabad      Indian   241.0
# 128       Pat Cummins             37.0    Kolkata    Overseas   316.0
# 154         K Gowtham             24.0    Lucknow      Indian   186.0
# 218       Glen Maxwell            97.0  Bangalore    Overseas  2018.0
# 233    Kieron Pollard            178.0     Mumbai    Overseas  3268.0
# 204      Andre Russell            84.0    Kolkata    Overseas  1700.0
# ...

# %%
#top allrounder with highest bowling strike rate
top_allrounder_Bowling_SR
# Out:
#            Player Name  Matches_Played       Team Nationality    Runs  \
# 202         Aman Khan              5.0    Kolkata      Indian    40.0
# 204      Andre Russell            84.0    Kolkata    Overseas  1700.0
# 165       Jofra Archer            35.0     Mumbai    Overseas   195.0
# 139   Abhishek Sharma             22.0  Hyderabad      Indian   241.0
# 211      Hardik Pandya            92.0    Gujarat      Indian  1476.0
# 169  Mithchel Santner              6.0    Chennai    Overseas    32.0
# 233    Kieron Pollard            178.0     Mumbai    Overseas  3268.0
# 232      Sunil Narine            134.0    Kolkata    Overseas   954.0
# 128       Pat Cummins             37.0    Kolkata    Overseas   316.0
# 223          Moeen Ali            34.0    Chennai    Overseas   666.0
# 195     Mohammad Nabi             17.0    Kolkata    Overseas   180.0
# 218       Glen Maxwell            97.0  Bangalore    Overseas  2018.0
# ...

# %% [markdown]
# After analyzing the data of the top allrounders we can see that:
# 1.Kieron Pollard has played most number of matches till now and also has the highest runs among all the allrounders.
# 2.Andre Russell highest strike_rate both in Batting and Bowling( we can ignore Aman Khan as his Bowling_strike_Rate is 0.0)
# 3.Sunil Narine has taken the most number of wickets and also the most economical bowler among all the allrounders.
# 4.Mithchel Santner is the allrounder with highest average
# 5.Jofra Archer is the allrounder with highest Bowling average(here also we ignore Aman Khan as his Bowling_Average is 0.0)

# %%
#analysing the data of wicket-keepers with average more than or equal to 25.0
top_WKs=capped_WKs.loc[(capped_WKs['Average']>=25.0)]
top_WKs
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 105  Quinton De Kock            77.0    Lucknow    Overseas  2256.0    31.30
# 106    Ambati Rayudu           175.0    Chennai      Indian  3916.0    29.40
# 107     Ishan Kishan            61.0     Mumbai      Indian  1452.0    28.50
# 108   Jonny Bairstow            28.0     Punjab    Overseas  1038.0    41.50
# 109   Dinesh Karthik           213.0  Bangalore      Indian  4046.0    25.80
# 111        KS Bharat             8.0      Delhi      Indian   191.0    38.20
# 206    Rishabh Pant             84.0      Delhi      Indian  2498.0    35.18
# 209     Sanju Samson           121.0  Rajasthan      Indian  3068.0    29.22
# 213         MS Dhoni           220.0    Chennai      Indian  4746.0    39.50
# 219       Jos Butler            65.0  Rajasthan    Overseas  1968.0    35.14
#
#      Strike_Rate  Catches  Stumps  Run_outs
# 105       130.90     53.0    14.0       0.0
# ...

# %%
#sorting the top_wicket-keepers data in descending order with respect to each parameters
top_WKs_matches=top_WKs.sort_values('Matches_Played',ascending=False)
top_WKs_runs=top_WKs.sort_values('Runs',ascending=False)
top_WKs_avg=top_WKs.sort_values('Average',ascending=False)
top_WKs_SR=top_WKs.sort_values('Strike_Rate',ascending=False)
top_WKs_catches=top_WKs.sort_values('Catches',ascending=False)
top_WKs_stumps=top_WKs.sort_values('Stumps',ascending=False)
top_WKs_ROs=top_WKs.sort_values('Run_outs',ascending=False)

# %%
top_WKs_matches
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 213         MS Dhoni           220.0    Chennai      Indian  4746.0    39.50
# 109   Dinesh Karthik           213.0  Bangalore      Indian  4046.0    25.80
# 106    Ambati Rayudu           175.0    Chennai      Indian  3916.0    29.40
# 209     Sanju Samson           121.0  Rajasthan      Indian  3068.0    29.22
# 206    Rishabh Pant             84.0      Delhi      Indian  2498.0    35.18
# 105  Quinton De Kock            77.0    Lucknow    Overseas  2256.0    31.30
# 219       Jos Butler            65.0  Rajasthan    Overseas  1968.0    35.14
# 107     Ishan Kishan            61.0     Mumbai      Indian  1452.0    28.50
# 108   Jonny Bairstow            28.0     Punjab    Overseas  1038.0    41.50
# 111        KS Bharat             8.0      Delhi      Indian   191.0    38.20
#
#      Strike_Rate  Catches  Stumps  Run_outs
# 213       135.80    126.0    39.0      21.0
# ...

# %%
top_WKs_runs
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 213         MS Dhoni           220.0    Chennai      Indian  4746.0    39.50
# 109   Dinesh Karthik           213.0  Bangalore      Indian  4046.0    25.80
# 106    Ambati Rayudu           175.0    Chennai      Indian  3916.0    29.40
# 209     Sanju Samson           121.0  Rajasthan      Indian  3068.0    29.22
# 206    Rishabh Pant             84.0      Delhi      Indian  2498.0    35.18
# 105  Quinton De Kock            77.0    Lucknow    Overseas  2256.0    31.30
# 219       Jos Butler            65.0  Rajasthan    Overseas  1968.0    35.14
# 107     Ishan Kishan            61.0     Mumbai      Indian  1452.0    28.50
# 108   Jonny Bairstow            28.0     Punjab    Overseas  1038.0    41.50
# 111        KS Bharat             8.0      Delhi      Indian   191.0    38.20
#
#      Strike_Rate  Catches  Stumps  Run_outs
# 213       135.80    126.0    39.0      21.0
# ...

# %%
top_WKs_catches
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 213         MS Dhoni           220.0    Chennai      Indian  4746.0    39.50
# 109   Dinesh Karthik           213.0  Bangalore      Indian  4046.0    25.80
# 209     Sanju Samson           121.0  Rajasthan      Indian  3068.0    29.22
# 106    Ambati Rayudu           175.0    Chennai      Indian  3916.0    29.40
# 206    Rishabh Pant             84.0      Delhi      Indian  2498.0    35.18
# 105  Quinton De Kock            77.0    Lucknow    Overseas  2256.0    31.30
# 219       Jos Butler            65.0  Rajasthan    Overseas  1968.0    35.14
# 107     Ishan Kishan            61.0     Mumbai      Indian  1452.0    28.50
# 108   Jonny Bairstow            28.0     Punjab    Overseas  1038.0    41.50
# 111        KS Bharat             8.0      Delhi      Indian   191.0    38.20
#
#      Strike_Rate  Catches  Stumps  Run_outs
# 213       135.80    126.0    39.0      21.0
# ...

# %%
top_WKs_avg
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 108   Jonny Bairstow            28.0     Punjab    Overseas  1038.0    41.50
# 213         MS Dhoni           220.0    Chennai      Indian  4746.0    39.50
# 111        KS Bharat             8.0      Delhi      Indian   191.0    38.20
# 206    Rishabh Pant             84.0      Delhi      Indian  2498.0    35.18
# 219       Jos Butler            65.0  Rajasthan    Overseas  1968.0    35.14
# 105  Quinton De Kock            77.0    Lucknow    Overseas  2256.0    31.30
# 106    Ambati Rayudu           175.0    Chennai      Indian  3916.0    29.40
# 209     Sanju Samson           121.0  Rajasthan      Indian  3068.0    29.22
# 107     Ishan Kishan            61.0     Mumbai      Indian  1452.0    28.50
# 109   Dinesh Karthik           213.0  Bangalore      Indian  4046.0    25.80
#
#      Strike_Rate  Catches  Stumps  Run_outs
# 108       142.20     18.0     4.0       1.0
# ...

# %%
top_WKs_stumps
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 213         MS Dhoni           220.0    Chennai      Indian  4746.0    39.50
# 109   Dinesh Karthik           213.0  Bangalore      Indian  4046.0    25.80
# 105  Quinton De Kock            77.0    Lucknow    Overseas  2256.0    31.30
# 206    Rishabh Pant             84.0      Delhi      Indian  2498.0    35.18
# 209     Sanju Samson           121.0  Rajasthan      Indian  3068.0    29.22
# 108   Jonny Bairstow            28.0     Punjab    Overseas  1038.0    41.50
# 106    Ambati Rayudu           175.0    Chennai      Indian  3916.0    29.40
# 107     Ishan Kishan            61.0     Mumbai      Indian  1452.0    28.50
# 111        KS Bharat             8.0      Delhi      Indian   191.0    38.20
# 219       Jos Butler            65.0  Rajasthan    Overseas  1968.0    35.14
#
#      Strike_Rate  Catches  Stumps  Run_outs
# 213       135.80    126.0    39.0      21.0
# ...

# %%
top_WKs_SR
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 219       Jos Butler            65.0  Rajasthan    Overseas  1968.0    35.14
# 206    Rishabh Pant             84.0      Delhi      Indian  2498.0    35.18
# 108   Jonny Bairstow            28.0     Punjab    Overseas  1038.0    41.50
# 107     Ishan Kishan            61.0     Mumbai      Indian  1452.0    28.50
# 213         MS Dhoni           220.0    Chennai      Indian  4746.0    39.50
# 209     Sanju Samson           121.0  Rajasthan      Indian  3068.0    29.22
# 105  Quinton De Kock            77.0    Lucknow    Overseas  2256.0    31.30
# 109   Dinesh Karthik           213.0  Bangalore      Indian  4046.0    25.80
# 106    Ambati Rayudu           175.0    Chennai      Indian  3916.0    29.40
# 111        KS Bharat             8.0      Delhi      Indian   191.0    38.20
#
#      Strike_Rate  Catches  Stumps  Run_outs
# 219       150.00     34.0     1.0       3.0
# ...

# %%
top_WKs_ROs
# Out:
#          Player Name  Matches_Played       Team Nationality    Runs  Average  \
# 213         MS Dhoni           220.0    Chennai      Indian  4746.0    39.50
# 109   Dinesh Karthik           213.0  Bangalore      Indian  4046.0    25.80
# 106    Ambati Rayudu           175.0    Chennai      Indian  3916.0    29.40
# 209     Sanju Samson           121.0  Rajasthan      Indian  3068.0    29.22
# 206    Rishabh Pant             84.0      Delhi      Indian  2498.0    35.18
# 219       Jos Butler            65.0  Rajasthan    Overseas  1968.0    35.14
# 107     Ishan Kishan            61.0     Mumbai      Indian  1452.0    28.50
# 108   Jonny Bairstow            28.0     Punjab    Overseas  1038.0    41.50
# 105  Quinton De Kock            77.0    Lucknow    Overseas  2256.0    31.30
# 111        KS Bharat             8.0      Delhi      Indian   191.0    38.20
#
#      Strike_Rate  Catches  Stumps  Run_outs
# 213       135.80    126.0    39.0      21.0
# ...

# %% [markdown]
#  after analyzing the data we can see that:
#  1.MS Dhoni holds the records of the most matches_played,Most runs,Most stumps,Most catches and Most Runouts.
#  2.Jos Butler has the highest strike rate among all the wicket-keepers
#  3.Jonny Bairstow has the highest average among all the wicket-keepers

# %% [markdown]
# # Data Visualization

# %% [markdown]
# to get the better analysis of the data we will do visual representation of the data

# %% [markdown]
# # visualization of batters data

# %%
#this plot shows the number of matches Played by all the top batters

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_batters)
# Out:
# <Axes: xlabel='Player Name', ylabel='Matches_Played'>

# %%
#this plot shows the number of runs scored by all the top batters

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Runs',data=top_batters)
# Out:
# <Axes: xlabel='Player Name', ylabel='Runs'>

# %%
#this plot shows the average of all the top batters

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Average',data=top_batters)
# Out:
# <Axes: xlabel='Player Name', ylabel='Average'>

# %%
#this plot shows the strike rate of all the top batters

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_batters)
# Out:
# <Axes: xlabel='Player Name', ylabel='Strike_Rate'>

# %% [markdown]
# After visualizing and comparing all the data of the top batters with respect to all the parameters top 3 batters should be:
# 1.Virat Kohli
# 2.David Werner and
# 3.KL Rahul

# %% [markdown]
# # visualisation of allrounders data

# %%
#thid plot shows the number of matches played by all the top allrounders 

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Matches_Played'>

# %%
#this plot shows the runs scored by all the top allrounders

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Runs',data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Runs'>

# %%
#this plot shows batting average of all the top allrounders

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Average',data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Average'>

# %%
#this plot shows the strike rate of all the top allrounders

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Strike_Rate'>

# %%
#this plot shows the number of wickets taken by the top allrounders 

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Wickets',data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Wickets'>

# %%
#this plot shows the bowling average of all the top all rounders

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Bowling_average',data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Bowling_average'>

# %%
#thid plot shows the economy of all the top allrounders

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Economy',data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Economy'>

# %%
#this plot shows the bowling strike rate of all the top allrounders

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Bowling_Strike_Rate',data=top_allrounders)
# Out:
# <Axes: xlabel='Player Name', ylabel='Bowling_Strike_Rate'>

# %% [markdown]
# After visualizing and comparing all the data of top allrounders with respect to all the parameters we conclude that top 4 allrounders should be:
# 1.Kieron Pollard
# 2.Andre Russell
# 3.Sunil Narine and
# 4.Hardik Pandya

# %% [markdown]
# # Visualisation of wicket_keepers data

# %%
#this plot shows the number of matches played by all the top wicket keepers

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_WKs)
# Out:
# <Axes: xlabel='Player Name', ylabel='Matches_Played'>

# %%
#this plot shows the number of runs scored by all the top wicket keepers

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Runs',data=top_WKs)
# Out:
# <Axes: xlabel='Player Name', ylabel='Runs'>

# %%
#this plot shows the batting average of all the top wicket-keepers

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Average',data=top_WKs)
# Out:
# <Axes: xlabel='Player Name', ylabel='Average'>

# %%
#this plot shows the strike rate of all the top wicket keepers

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_WKs)
# Out:
# <Axes: xlabel='Player Name', ylabel='Strike_Rate'>

# %%
#this plot shows the number of catches taken by the top wicket keepers

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Catches',data=top_WKs)
# Out:
# <Axes: xlabel='Player Name', ylabel='Catches'>

# %%
#this plot shows the number of stumping done by the top wicket_keepers

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Stumps',data=top_WKs)
# Out:
# <Axes: xlabel='Player Name', ylabel='Stumps'>

# %%
#this plot shows the number of run_outs by top Wicket-keepers

plt.figure(figsize=(30,10))
sns.barplot(x='Player Name',y='Run_outs',data=top_WKs)
# Out:
# <Axes: xlabel='Player Name', ylabel='Run_outs'>

# %% [markdown]
# After visualizing and comparing all the data of top wicket_keepers with respect to all the parameters we conclude that top 4 wicket-keepers should be: 1.MS Dhoni 2.Dinesh Karthik 3.Rishabh Pant and 4.Sanju Samson

# %% [markdown]
# # conclusion

# %% [markdown]
# After analyzing the IPL 2022 dataset we can conclude that excluding the bowlers the top 11 players which include only Batters,Allrounders and Wicket_keepers are:
# 1.Virat Kohli , 2.David Werner , 3.KL Rahul, 4.Kieron Pollard , 5.Andre Russell , 6.Sunil Narine, 7.Hardik Pandya, 8.MS Dhoni, 9.Dinesh Karthik , 10.Rishabh Pant and 11.Sanju Samson
